# %% [markdown]
# <a href="https://colab.research.google.com/github/HasibullahAman/IBMAIEngineeringProfessionalCertificate/blob/Introduction-to-Deep-Learning-%26-Neural-Networks-with-Keras/Increase_the_number_of_hidden_layers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><span style="font-family:Comic Sans MS; color:navy "><h1>Task4</h1></span></center>

# %% [markdown]
# ## Import library's

# %%
# i had just need this for preprocessing 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# I need this for my Neural network model
from keras.models import Sequential
from keras.layers import Dense
# for split data
from sklearn.model_selection import train_test_split
# for test our model
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Import Data

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# ## Preprocessing & Normalization

# %%
concrete_data_columns = concrete_data.columns
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# in the cell above I split the target and and my data, like the lab we have befor

# %%
predictors = (predictors - predictors.mean()) / predictors.std()
predictors.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# ## Create a Neural Network

# %%
model = Sequential() # create a instance from sequential model
# Add a fully connected (Dense) layer with 10 units and ReLU activation
model.add(Dense(10,activation='relu'))
# add tow ohter layer in task 4
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(1)) # I got error and I add this layer ---> https://stackoverflow.com/questions/60988136/calculating-mean-square-error-return-y-true-and-y-pred-have-different-number-of
# Compile the model with binary mean_squerd_error and Adam optimizer
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=0)

# %%
model.fit(X_train, y_train, epochs=100) # in this notebook I have just change the number of epochs
# Out:
# Epoch 1/100
# 23/23 [==============================] - 1s 2ms/step - loss: 1563.4967
# Epoch 2/100
# 23/23 [==============================] - 0s 2ms/step - loss: 1542.7043
# Epoch 3/100
# 23/23 [==============================] - 0s 3ms/step - loss: 1511.0424
# Epoch 4/100
# 23/23 [==============================] - 0s 2ms/step - loss: 1456.6167
# Epoch 5/100
# 23/23 [==============================] - 0s 2ms/step - loss: 1360.4241
# Epoch 6/100
# 23/23 [==============================] - 0s 2ms/step - loss: 1211.5298
# Epoch 7/100
# 23/23 [==============================] - 0s 3ms/step - loss: 1005.5318
# Epoch 8/100
# 23/23 [==============================] - 0s 3ms/step - loss: 784.6572
# Epoch 9/100
# 23/23 [==============================] - 0s 2ms/step - loss: 610.0442
# Epoch 10/100
# 23/23 [==============================] - 0s 2ms/step - loss: 506.9952
# Epoch 11/100
# 23/23 [==============================] - 0s 2ms/step - loss: 437.6122
# Epoch 12/100
# ...

# %%
mse_list = []
for i in range(50):
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_list.append(mse)
# Out:
# ...
# 10/10 [==============================] - 0s 2ms/step

# %%
# Report the mean and standard deviation of the mean squared errors after we add tow other layer
print(np.mean(mse_list))
print(np.std(mse_list))
# Out:
# 69.14700466892762
# 0.0
